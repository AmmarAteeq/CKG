# %%
import os
import torch
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import LogLocator
import numpy as np
from torch_geometric.utils import degree

# %%
import sys
sys.path.insert(0, "./Neo4jToPyGGraph/")

# %%
import os
from impl.GraphRetriever import GraphRetriever

# %%
from tqdm.notebook import tqdm

# %%
os.getcwd()
# Out:
# '/Users/ammar.ateeq'

# %%
# So here you need to calculate the degree a bit different 
# Count occurrencces (either there is some numpy utility or you can use simple for loops) but you can directly update the node properties by adding new properties

# %%
URI = "bolt://localhost:7687"
AUTH = ("neo4j", "password")

graphRetriever = GraphRetriever(URI, AUTH)

# %%
import numpy as np
import pandas as pd

class DegreeCalculator:
    def __init__(self):
        self.node_dict = dict()
        
    def set_degree_dict(self, unique_idx, count_idx, dict_type, tuple_names):
        source_type, edge_type, target_type = tuple_names 
        for i, node_id in enumerate(unique_idx):
            node_id_dict = self.node_dict.get(node_id, dict())
            self.node_dict[node_id] = node_id_dict
            count_node_id = count_idx[i]
            node_degree_dict = node_id_dict.get(dict_type, dict())
            self.node_dict[node_id][dict_type] = node_degree_dict
            node_degree_dict[f"{source_type}_{edge_type}_{target_type}"] = count_node_id
            
    def add_edge_index_to_node_dict(self, tuple_names, edge_index):
        source_index = edge_index[0]
        target_index = edge_index[1]
        unique_source_idx, count_source_index = np.unique(source_index, return_counts = True)
        unique_target_idx, count_target_index = np.unique(target_index, return_counts = True)
    
        self.set_degree_dict(unique_source_idx, count_source_index, "node_out_degree_dict", tuple_names)
        self.set_degree_dict(unique_target_idx, count_target_index, "node_in_degree_dict", tuple_names)

    def write_degree_summaries(self):
        for node_id in self.node_dict.keys():
            node_out_degree_dict = self.node_dict[node_id].get("node_out_degree_dict", dict())
            node_in_degree_dict = self.node_dict[node_id].get("node_in_degree_dict", dict())
            self.node_dict[node_id]["out_degree"] = sum(node_out_degree_dict.values())
            self.node_dict[node_id]["in_degree"] = sum(node_in_degree_dict.values())
            self.node_dict[node_id]["degree"] = self.node_dict[node_id]["in_degree"] + self.node_dict[node_id]["out_degree"]

    def calculate_node_dict(self, folder_path):
        for file_name in os.listdir(folder_path):
            if file_name.endswith('.csv'):
                full_file_path = os.path.join(folder_path, file_name)
                edge_index = pd.read_csv(full_file_path).values.transpose()
                tuple_names = file_name[:-4].split("__")
                self.add_edge_index_to_node_dict(tuple_names, edge_index)
                
        self.write_degree_summaries()
        

    def get_node_dict(self):
        return self.node_dict

# %%
"""USAGE:

##Basic usage
file_names = ["DRUG_ACTS_ON_PROTEIN.csv"]
degree_calculator = DegreeCalculator()
degree_calculator.calculate_node_dict(file_names)
node_dict = degree_calculator.get_node_dict()
node_dict

## Write to db
for key in node_dict:
    property_dict = node_dict[key]
    query = f'''MATCH (n)
        WHERE id(n) = {key}
        SET n.degree_dict = "{property_dict}"'''
    session.run(query)
"""

# %%
folder_path = 'data_with_orginal_id_all/'  

degree_calculator = DegreeCalculator()
degree_calculator.calculate_node_dict(folder_path)
node_dict = degree_calculator.get_node_dict()
node_dict
# Out:
# {415186: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 281,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ACTS_ON_Protein': 16,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 9,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 5,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 149,
#    'Protein_ASSOCIATED_WITH_Biological_process': 17,
#    'Protein_ASSOCIATED_WITH_Tissue': 275,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 223,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 48},
#   'node_in_degree_dict': {'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 465,
#    'Protein_ACTS_ON_Protein': 12,
#    'Drug_COMPILED_TARGETS_Protein': 21,
#    'Drug_ACTS_ON_Protein': 34,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 1,
#    'Transcript_TRANSLATED_INTO_Protein': 1,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 48},
#   'out_degree': 1040,
#   'in_degree': 583,
#   'degree': 1623},
#  415187: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 418,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 3,
#    'Protein_ACTS_ON_Protein': 5,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 6,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 24,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 4,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 381,
#    'Protein_ASSOCIATED_WITH_Biological_process': 4,
#    'Protein_ASSOCIATED_WITH_Tissue': 520,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 2909,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 93},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 173,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 599,
#    'Protein_ACTS_ON_Protein': 3,
#    'Drug_COMPILED_TARGETS_Protein': 33,
#    'Drug_ACTS_ON_Protein': 38,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 8,
#    'Transcript_TRANSLATED_INTO_Protein': 1,
#    'Functional_region_FOUND_IN_PROTEIN_Protein': 2,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Analytical_sample_HAS_QUANTIFIED_PROTEIN_Protein': 39,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 93},
#   'out_degree': 4384,
#   'in_degree': 990,
#   'degree': 5374},
#  415188: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 50,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ACTS_ON_Protein': 85,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 2,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 3,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 2,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 67,
#    'Protein_ASSOCIATED_WITH_Biological_process': 1,
#    'Protein_ASSOCIATED_WITH_Tissue': 115,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 40,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 56,
#    'Protein_HAS_STRUCTURE_Protein_structure': 1},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 51,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 453,
#    'Protein_ACTS_ON_Protein': 75,
#    'Drug_COMPILED_TARGETS_Protein': 42,
#    'Drug_ACTS_ON_Protein': 56,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 1,
#    'Transcript_TRANSLATED_INTO_Protein': 1,
#    'Functional_region_FOUND_IN_PROTEIN_Protein': 2,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 56},
#   'out_degree': 439,
#   'in_degree': 738,
#   'degree': 1177},
#  415192: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 147,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 7,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 133,
#    'Protein_ASSOCIATED_WITH_Tissue': 203,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 195,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 24},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 16,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 545,
#    'Drug_ACTS_ON_Protein': 6,
#    'Transcript_TRANSLATED_INTO_Protein': 4,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 24},
#   'out_degree': 726,
#   'in_degree': 596,
#   'degree': 1322},
#  415195: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 349,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ACTS_ON_Protein': 6,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 3,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 19,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 16,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 153,
#    'Protein_ASSOCIATED_WITH_Biological_process': 1,
#    'Protein_ASSOCIATED_WITH_Tissue': 319,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 163,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 78,
#    'Protein_HAS_STRUCTURE_Protein_structure': 2},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 44,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 586,
#    'Protein_ACTS_ON_Protein': 27,
#    'Drug_COMPILED_TARGETS_Protein': 2,
#    'Drug_ACTS_ON_Protein': 7,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 13,
#    'Transcript_TRANSLATED_INTO_Protein': 4,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Analytical_sample_HAS_QUANTIFIED_PROTEIN_Protein': 16,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 78},
#   'out_degree': 1126,
#   'in_degree': 778,
#   'degree': 1904},
#  415196: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 201,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 10,
#    'Protein_ACTS_ON_Protein': 4,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 4,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 2,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 41,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 120,
#    'Protein_ASSOCIATED_WITH_Biological_process': 2,
#    'Protein_ASSOCIATED_WITH_Tissue': 203,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 241,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 59},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 17,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 373,
#    'Protein_ACTS_ON_Protein': 5,
#    'Drug_COMPILED_TARGETS_Protein': 34,
#    'Metabolite_ASSOCIATED_WITH_Protein': 15,
#    'Drug_ACTS_ON_Protein': 38,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 17,
#    'Transcript_TRANSLATED_INTO_Protein': 8,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 59},
#   'out_degree': 904,
#   'in_degree': 567,
#   'degree': 1471},
#  415201: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 160,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 1,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 4,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 5,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 13,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 116,
#    'Protein_ASSOCIATED_WITH_Biological_process': 5,
#    'Protein_ASSOCIATED_WITH_Tissue': 221,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 171,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 51},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 26,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 300,
#    'Protein_ACTS_ON_Protein': 4,
#    'Drug_COMPILED_TARGETS_Protein': 41,
#    'Metabolite_ASSOCIATED_WITH_Protein': 1076,
#    'Drug_ACTS_ON_Protein': 49,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 2,
#    'Transcript_TRANSLATED_INTO_Protein': 1,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 51},
#   'out_degree': 764,
#   'in_degree': 1551,
#   'degree': 2315},
#  415206: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 88,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 1,
#    'Protein_ACTS_ON_Protein': 2,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 2,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 27,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 105,
#    'Protein_ASSOCIATED_WITH_Biological_process': 3,
#    'Protein_ASSOCIATED_WITH_Tissue': 178,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 78,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 40,
#    'Protein_HAS_STRUCTURE_Protein_structure': 3},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 54,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 623,
#    'Protein_ACTS_ON_Protein': 15,
#    'Drug_COMPILED_TARGETS_Protein': 3,
#    'Drug_ACTS_ON_Protein': 3,
#    'Transcript_TRANSLATED_INTO_Protein': 8,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 40},
#   'out_degree': 544,
#   'in_degree': 747,
#   'degree': 1291},
#  415216: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 619,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 8,
#    'Protein_ACTS_ON_Protein': 155,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 6,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 131,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 2,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 576,
#    'Protein_ASSOCIATED_WITH_Biological_process': 11,
#    'Protein_ASSOCIATED_WITH_Tissue': 817,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 1869,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 306,
#    'Protein_HAS_STRUCTURE_Protein_structure': 24},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 384,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 784,
#    'Protein_ACTS_ON_Protein': 30,
#    'Drug_COMPILED_TARGETS_Protein': 24,
#    'Metabolite_ASSOCIATED_WITH_Protein': 7,
#    'Drug_ACTS_ON_Protein': 31,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 28,
#    'Transcript_TRANSLATED_INTO_Protein': 5,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Analytical_sample_HAS_QUANTIFIED_PROTEIN_Protein': 54,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 306},
#   'out_degree': 4541,
#   'in_degree': 1654,
#   'degree': 6195},
#  415218: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 206,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 1,
#    'Protein_ACTS_ON_Protein': 2,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 9,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 13,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 92,
#    'Protein_ASSOCIATED_WITH_Biological_process': 3,
#    'Protein_ASSOCIATED_WITH_Tissue': 153,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 164,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 34},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 45,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 383,
#    'Drug_COMPILED_TARGETS_Protein': 28,
#    'Metabolite_ASSOCIATED_WITH_Protein': 5,
#    'Drug_ACTS_ON_Protein': 27,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 1,
#    'Transcript_TRANSLATED_INTO_Protein': 1,
#    'Functional_region_FOUND_IN_PROTEIN_Protein': 2,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 34},
#   'out_degree': 694,
#   'in_degree': 527,
#   'degree': 1221},
#  415219: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 396,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 12,
#    'Protein_ACTS_ON_Protein': 7,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 8,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 28,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 9,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 233,
#    'Protein_ASSOCIATED_WITH_Biological_process': 12,
#    'Protein_ASSOCIATED_WITH_Tissue': 417,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 1232,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 112,
#    'Protein_HAS_STRUCTURE_Protein_structure': 2},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 195,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 711,
#    'Protein_ACTS_ON_Protein': 49,
#    'Metabolite_ASSOCIATED_WITH_Protein': 35,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 18,
#    'Transcript_TRANSLATED_INTO_Protein': 3,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Analytical_sample_HAS_QUANTIFIED_PROTEIN_Protein': 40,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 112},
#   'out_degree': 2485,
#   'in_degree': 1164,
#   'degree': 3649},
#  415220: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 149,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 24,
#    'Protein_ACTS_ON_Protein': 662,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 3,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 11,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 5,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 128,
#    'Protein_ASSOCIATED_WITH_Biological_process': 15,
#    'Protein_ASSOCIATED_WITH_Tissue': 299,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 169,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 279},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 25,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 361,
#    'Protein_ACTS_ON_Protein': 5,
#    'Drug_COMPILED_TARGETS_Protein': 1,
#    'Drug_ACTS_ON_Protein': 3,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 5,
#    'Modified_protein_IS_SUBSTRATE_OF_Protein': 5,
#    'Transcript_TRANSLATED_INTO_Protein': 1,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Analytical_sample_HAS_QUANTIFIED_PROTEIN_Protein': 14,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 279},
#   'out_degree': 1761,
#   'in_degree': 700,
#   'degree': 2461},
#  415223: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 286,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 6,
#    'Protein_ACTS_ON_Protein': 133,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 8,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 2,
#    'Protein_IS_SUBUNIT_OF_Complex': 1,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 170,
#    'Protein_ASSOCIATED_WITH_Biological_process': 12,
#    'Protein_ASSOCIATED_WITH_Tissue': 330,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 597,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 156,
#    'Protein_HAS_STRUCTURE_Protein_structure': 3},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 1,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 474,
#    'Protein_ACTS_ON_Protein': 23,
#    'Drug_COMPILED_TARGETS_Protein': 35,
#    'Metabolite_ASSOCIATED_WITH_Protein': 1,
#    'Drug_ACTS_ON_Protein': 56,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 4,
#    'Transcript_TRANSLATED_INTO_Protein': 2,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 156},
#   'out_degree': 1721,
#   'in_degree': 753,
#   'degree': 2474},
#  415224: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 111,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 4,
#    'Protein_ACTS_ON_Protein': 33,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 7,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 3,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 118,
#    'Protein_ASSOCIATED_WITH_Biological_process': 15,
#    'Protein_ASSOCIATED_WITH_Tissue': 152,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 148,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 79,
#    'Protein_HAS_STRUCTURE_Protein_structure': 1},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 23,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 444,
#    'Protein_ACTS_ON_Protein': 30,
#    'Drug_COMPILED_TARGETS_Protein': 22,
#    'Metabolite_ASSOCIATED_WITH_Protein': 54,
#    'Drug_ACTS_ON_Protein': 23,
#    'Transcript_TRANSLATED_INTO_Protein': 1,
#    'Functional_region_FOUND_IN_PROTEIN_Protein': 2,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 79},
#   'out_degree': 688,
#   'in_degree': 679,
#   'degree': 1367},
#  415228: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 174,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 1,
#    'Protein_ACTS_ON_Protein': 1,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 12,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 5,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 177,
#    'Protein_ASSOCIATED_WITH_Biological_process': 9,
#    'Protein_ASSOCIATED_WITH_Tissue': 328,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 220,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 28},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 29,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 714,
#    'Protein_ACTS_ON_Protein': 9,
#    'Transcript_TRANSLATED_INTO_Protein': 8,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 28},
#   'out_degree': 972,
#   'in_degree': 789,
#   'degree': 1761},
#  415231: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 114,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ACTS_ON_Protein': 52,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 2,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 49,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 201,
#    'Protein_ASSOCIATED_WITH_Biological_process': 4,
#    'Protein_ASSOCIATED_WITH_Tissue': 271,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 151,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 39,
#    'Protein_HAS_STRUCTURE_Protein_structure': 1},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 169,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 498,
#    'Protein_ACTS_ON_Protein': 21,
#    'Metabolite_ASSOCIATED_WITH_Protein': 12,
#    'Drug_ACTS_ON_Protein': 6,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 8,
#    'Transcript_TRANSLATED_INTO_Protein': 1,
#    'Functional_region_FOUND_IN_PROTEIN_Protein': 4,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Analytical_sample_HAS_QUANTIFIED_PROTEIN_Protein': 35,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 39},
#   'out_degree': 901,
#   'in_degree': 794,
#   'degree': 1695},
#  415234: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 239,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 3,
#    'Protein_ACTS_ON_Protein': 6,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 3,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 36,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 170,
#    'Protein_ASSOCIATED_WITH_Biological_process': 6,
#    'Protein_ASSOCIATED_WITH_Tissue': 289,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 348,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 109},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 10,
#    'Protein_ACTS_ON_Protein': 51,
#    'Drug_COMPILED_TARGETS_Protein': 2,
#    'Drug_ACTS_ON_Protein': 10,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 2,
#    'Transcript_TRANSLATED_INTO_Protein': 1,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 109},
#   'out_degree': 1226,
#   'in_degree': 186,
#   'degree': 1412},
#  415235: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 131,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 1,
#    'Protein_ACTS_ON_Protein': 3,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 5,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 1,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 1,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 62,
#    'Protein_ASSOCIATED_WITH_Biological_process': 7,
#    'Protein_ASSOCIATED_WITH_Tissue': 119,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 70,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 24},
#   'node_in_degree_dict': {'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 433,
#    'Protein_ACTS_ON_Protein': 9,
#    'Drug_COMPILED_TARGETS_Protein': 27,
#    'Metabolite_ASSOCIATED_WITH_Protein': 1,
#    'Drug_ACTS_ON_Protein': 51,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 1,
#    'Transcript_TRANSLATED_INTO_Protein': 4,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 24},
#   'out_degree': 441,
#   'in_degree': 551,
#   'degree': 992},
#  415237: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 229,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 2,
#    'Protein_ACTS_ON_Protein': 300,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 8,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 3,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 5,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 131,
#    'Protein_ASSOCIATED_WITH_Biological_process': 5,
#    'Protein_ASSOCIATED_WITH_Tissue': 310,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 349,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 264},
#   'node_in_degree_dict': {'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 331,
#    'Protein_ACTS_ON_Protein': 178,
#    'Drug_COMPILED_TARGETS_Protein': 87,
#    'Metabolite_ASSOCIATED_WITH_Protein': 4,
#    'Drug_ACTS_ON_Protein': 353,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 2,
#    'Transcript_TRANSLATED_INTO_Protein': 2,
#    'Functional_region_FOUND_IN_PROTEIN_Protein': 1,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 264},
#   'out_degree': 1623,
#   'in_degree': 1223,
#   'degree': 2846},
#  415242: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 305,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 1,
#    'Protein_ACTS_ON_Protein': 6,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 5,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 168,
#    'Protein_IS_SUBUNIT_OF_Complex': 2,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 5,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 326,
#    'Protein_ASSOCIATED_WITH_Biological_process': 5,
#    'Protein_ASSOCIATED_WITH_Tissue': 452,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 604,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 90,
#    'Protein_HAS_STRUCTURE_Protein_structure': 1},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 353,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 1098,
#    'Drug_ACTS_ON_Protein': 4,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 53,
#    'Known_variant_CURATED_AFFECTS_INTERACTION_WITH_Protein': 2,
#    'Transcript_TRANSLATED_INTO_Protein': 6,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Analytical_sample_HAS_QUANTIFIED_PROTEIN_Protein': 22,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 90},
#   'out_degree': 1987,
#   'in_degree': 1629,
#   'degree': 3616},
#  415246: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 118,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ACTS_ON_Protein': 7,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 4,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 33,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 2,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 104,
#    'Protein_ASSOCIATED_WITH_Biological_process': 2,
#    'Protein_ASSOCIATED_WITH_Tissue': 239,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 95,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 126},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 126,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 657,
#    'Protein_ACTS_ON_Protein': 42,
#    'Drug_COMPILED_TARGETS_Protein': 3,
#    'Drug_ACTS_ON_Protein': 4,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 9,
#    'Known_variant_CURATED_AFFECTS_INTERACTION_WITH_Protein': 2,
#    'Transcript_TRANSLATED_INTO_Protein': 1,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Analytical_sample_HAS_QUANTIFIED_PROTEIN_Protein': 30,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 126},
#   'out_degree': 747,
#   'in_degree': 1001,
#   'degree': 1748},
#  415247: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 828,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 2,
#    'Protein_ACTS_ON_Protein': 15,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 12,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 12,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 2,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 306,
#    'Protein_ASSOCIATED_WITH_Biological_process': 18,
#    'Protein_ASSOCIATED_WITH_Tissue': 447,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 1020,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 91,
#    'Protein_HAS_STRUCTURE_Protein_structure': 6},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 74,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 879,
#    'Protein_ACTS_ON_Protein': 6,
#    'Drug_COMPILED_TARGETS_Protein': 10,
#    'Metabolite_ASSOCIATED_WITH_Protein': 1,
#    'Drug_ACTS_ON_Protein': 19,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 2,
#    'Transcript_TRANSLATED_INTO_Protein': 1,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Analytical_sample_HAS_QUANTIFIED_PROTEIN_Protein': 25,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 91},
#   'out_degree': 2776,
#   'in_degree': 1109,
#   'degree': 3885},
#  415250: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 28,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ACTS_ON_Protein': 19,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 1,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 29,
#    'Protein_ASSOCIATED_WITH_Tissue': 71,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 18,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 15},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 1,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 273,
#    'Protein_ACTS_ON_Protein': 23,
#    'Drug_COMPILED_TARGETS_Protein': 11,
#    'Drug_ACTS_ON_Protein': 22,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 15},
#   'out_degree': 198,
#   'in_degree': 346,
#   'degree': 544},
#  415253: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 502,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 4,
#    'Protein_ACTS_ON_Protein': 4,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 7,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 28,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 2,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 360,
#    'Protein_ASSOCIATED_WITH_Biological_process': 24,
#    'Protein_ASSOCIATED_WITH_Tissue': 548,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 1161,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 60},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 69,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 1677,
#    'Protein_ACTS_ON_Protein': 2,
#    'Drug_COMPILED_TARGETS_Protein': 5,
#    'Drug_ACTS_ON_Protein': 14,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 17,
#    'Transcript_TRANSLATED_INTO_Protein': 1,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Analytical_sample_HAS_QUANTIFIED_PROTEIN_Protein': 16,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 60},
#   'out_degree': 2717,
#   'in_degree': 1862,
#   'degree': 4579},
#  415262: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 363,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 2,
#    'Protein_ACTS_ON_Protein': 64,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 8,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 2,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 237,
#    'Protein_ASSOCIATED_WITH_Biological_process': 18,
#    'Protein_ASSOCIATED_WITH_Tissue': 399,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 598,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 96,
#    'Protein_HAS_STRUCTURE_Protein_structure': 5},
#   'node_in_degree_dict': {'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 477,
#    'Protein_ACTS_ON_Protein': 9,
#    'Drug_COMPILED_TARGETS_Protein': 27,
#    'Drug_ACTS_ON_Protein': 41,
#    'Transcript_TRANSLATED_INTO_Protein': 2,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 96},
#   'out_degree': 1809,
#   'in_degree': 653,
#   'degree': 2462},
#  415263: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 141,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 18,
#    'Protein_ACTS_ON_Protein': 30,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 6,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 15,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 18,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 142,
#    'Protein_ASSOCIATED_WITH_Biological_process': 4,
#    'Protein_ASSOCIATED_WITH_Tissue': 261,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 169,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 115,
#    'Protein_HAS_STRUCTURE_Protein_structure': 2},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 81,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 305,
#    'Protein_ACTS_ON_Protein': 13,
#    'Drug_COMPILED_TARGETS_Protein': 9,
#    'Metabolite_ASSOCIATED_WITH_Protein': 6,
#    'Drug_ACTS_ON_Protein': 13,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 26,
#    'Transcript_TRANSLATED_INTO_Protein': 1,
#    'Functional_region_FOUND_IN_PROTEIN_Protein': 2,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Analytical_sample_HAS_QUANTIFIED_PROTEIN_Protein': 36,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 115},
#   'out_degree': 938,
#   'in_degree': 608,
#   'degree': 1546},
#  415270: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 369,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 3,
#    'Protein_ACTS_ON_Protein': 211,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 4,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 11,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 3,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 276,
#    'Protein_ASSOCIATED_WITH_Biological_process': 13,
#    'Protein_ASSOCIATED_WITH_Tissue': 463,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 774,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 254},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 5,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 455,
#    'Protein_ACTS_ON_Protein': 138,
#    'Drug_COMPILED_TARGETS_Protein': 143,
#    'Metabolite_ASSOCIATED_WITH_Protein': 40,
#    'Drug_ACTS_ON_Protein': 499,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 9,
#    'Transcript_TRANSLATED_INTO_Protein': 1,
#    'Functional_region_FOUND_IN_PROTEIN_Protein': 1,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 254},
#   'out_degree': 2398,
#   'in_degree': 1546,
#   'degree': 3944},
#  415272: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 148,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 6,
#    'Protein_ACTS_ON_Protein': 8,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 4,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 13,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 2,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 225,
#    'Protein_ASSOCIATED_WITH_Biological_process': 4,
#    'Protein_ASSOCIATED_WITH_Tissue': 356,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 259,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 93},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 77,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 290,
#    'Protein_ACTS_ON_Protein': 2,
#    'Drug_COMPILED_TARGETS_Protein': 28,
#    'Metabolite_ASSOCIATED_WITH_Protein': 6,
#    'Drug_ACTS_ON_Protein': 22,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 4,
#    'Transcript_TRANSLATED_INTO_Protein': 1,
#    'Functional_region_FOUND_IN_PROTEIN_Protein': 1,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Analytical_sample_HAS_QUANTIFIED_PROTEIN_Protein': 52,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 93},
#   'out_degree': 1135,
#   'in_degree': 577,
#   'degree': 1712},
#  415278: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 282,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 5,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 3,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 2,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 145,
#    'Protein_ASSOCIATED_WITH_Biological_process': 6,
#    'Protein_ASSOCIATED_WITH_Tissue': 309,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 346,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 56},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 19,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 184,
#    'Protein_ACTS_ON_Protein': 2,
#    'Drug_COMPILED_TARGETS_Protein': 1,
#    'Drug_ACTS_ON_Protein': 5,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 7,
#    'Transcript_TRANSLATED_INTO_Protein': 2,
#    'Functional_region_FOUND_IN_PROTEIN_Protein': 1,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 56},
#   'out_degree': 1171,
#   'in_degree': 278,
#   'degree': 1449},
#  415279: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 187,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 16,
#    'Protein_ACTS_ON_Protein': 30,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 9,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 7,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 1,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 213,
#    'Protein_ASSOCIATED_WITH_Biological_process': 13,
#    'Protein_ASSOCIATED_WITH_Tissue': 320,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 1260,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 102},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 39,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 393,
#    'Protein_ACTS_ON_Protein': 1,
#    'Drug_COMPILED_TARGETS_Protein': 12,
#    'Metabolite_ASSOCIATED_WITH_Protein': 36,
#    'Drug_ACTS_ON_Protein': 12,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 5,
#    'Transcript_TRANSLATED_INTO_Protein': 1,
#    'Functional_region_FOUND_IN_PROTEIN_Protein': 3,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Analytical_sample_HAS_QUANTIFIED_PROTEIN_Protein': 3,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 102},
#   'out_degree': 2175,
#   'in_degree': 608,
#   'degree': 2783},
#  415282: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 133,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ACTS_ON_Protein': 17,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 3,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 10,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 2,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 124,
#    'Protein_ASSOCIATED_WITH_Biological_process': 2,
#    'Protein_ASSOCIATED_WITH_Tissue': 241,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 140,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 29},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 11,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 97,
#    'Protein_ACTS_ON_Protein': 9,
#    'Drug_COMPILED_TARGETS_Protein': 4,
#    'Drug_ACTS_ON_Protein': 4,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 3,
#    'Transcript_TRANSLATED_INTO_Protein': 1,
#    'Functional_region_FOUND_IN_PROTEIN_Protein': 1,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 29},
#   'out_degree': 718,
#   'in_degree': 160,
#   'degree': 878},
#  415287: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 343,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ACTS_ON_Protein': 4,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 8,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 3,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 1,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 215,
#    'Protein_ASSOCIATED_WITH_Biological_process': 7,
#    'Protein_ASSOCIATED_WITH_Tissue': 448,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 716,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 77,
#    'Protein_HAS_STRUCTURE_Protein_structure': 86},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 40,
#    'Protein_ACTS_ON_Protein': 9,
#    'Metabolite_ASSOCIATED_WITH_Protein': 6,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 15,
#    'Transcript_TRANSLATED_INTO_Protein': 7,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Analytical_sample_HAS_QUANTIFIED_PROTEIN_Protein': 26,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 77},
#   'out_degree': 1925,
#   'in_degree': 181,
#   'degree': 2106},
#  415298: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 44,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 1,
#    'Protein_ACTS_ON_Protein': 6,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 7,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 5,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 29,
#    'Protein_ASSOCIATED_WITH_Biological_process': 2,
#    'Protein_ASSOCIATED_WITH_Tissue': 102,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 35,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 14},
#   'node_in_degree_dict': {'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 399,
#    'Protein_ACTS_ON_Protein': 2,
#    'Drug_COMPILED_TARGETS_Protein': 12,
#    'Metabolite_ASSOCIATED_WITH_Protein': 45,
#    'Drug_ACTS_ON_Protein': 13,
#    'Transcript_TRANSLATED_INTO_Protein': 1,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 14},
#   'out_degree': 262,
#   'in_degree': 487,
#   'degree': 749},
#  415301: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 280,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 2,
#    'Protein_ACTS_ON_Protein': 154,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 3,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 5,
#    'Protein_IS_SUBUNIT_OF_Complex': 1,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 1,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 204,
#    'Protein_ASSOCIATED_WITH_Biological_process': 12,
#    'Protein_ASSOCIATED_WITH_Tissue': 300,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 319,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 175},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 15,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 279,
#    'Drug_COMPILED_TARGETS_Protein': 36,
#    'Drug_ACTS_ON_Protein': 56,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 22,
#    'Transcript_TRANSLATED_INTO_Protein': 1,
#    'Functional_region_FOUND_IN_PROTEIN_Protein': 1,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 175},
#   'out_degree': 1473,
#   'in_degree': 586,
#   'degree': 2059},
#  415302: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 444,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 5,
#    'Protein_ACTS_ON_Protein': 124,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 1,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 3,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 7,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 266,
#    'Protein_ASSOCIATED_WITH_Biological_process': 10,
#    'Protein_ASSOCIATED_WITH_Tissue': 359,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 3623,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 220,
#    'Protein_HAS_STRUCTURE_Protein_structure': 1},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 55,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 249,
#    'Protein_ACTS_ON_Protein': 30,
#    'Drug_COMPILED_TARGETS_Protein': 21,
#    'Drug_ACTS_ON_Protein': 33,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 9,
#    'Transcript_TRANSLATED_INTO_Protein': 1,
#    'Functional_region_FOUND_IN_PROTEIN_Protein': 1,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Analytical_sample_HAS_QUANTIFIED_PROTEIN_Protein': 128,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 220},
#   'out_degree': 5080,
#   'in_degree': 748,
#   'degree': 5828},
#  415310: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 204,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 23,
#    'Protein_ACTS_ON_Protein': 338,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 3,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 23,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 7,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 200,
#    'Protein_ASSOCIATED_WITH_Biological_process': 4,
#    'Protein_ASSOCIATED_WITH_Tissue': 329,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 233,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 302},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 56,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 220,
#    'Protein_ACTS_ON_Protein': 328,
#    'Drug_COMPILED_TARGETS_Protein': 3,
#    'Drug_ACTS_ON_Protein': 5,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 40,
#    'Transcript_TRANSLATED_INTO_Protein': 5,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Analytical_sample_HAS_QUANTIFIED_PROTEIN_Protein': 29,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 302},
#   'out_degree': 1683,
#   'in_degree': 989,
#   'degree': 2672},
#  415312: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 371,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 2,
#    'Protein_ACTS_ON_Protein': 1,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 10,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 32,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 1,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 243,
#    'Protein_ASSOCIATED_WITH_Biological_process': 32,
#    'Protein_ASSOCIATED_WITH_Tissue': 342,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 588,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 53},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 51,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 2280,
#    'Drug_COMPILED_TARGETS_Protein': 4,
#    'Drug_ACTS_ON_Protein': 21,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 3,
#    'Transcript_TRANSLATED_INTO_Protein': 2,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 53},
#   'out_degree': 1692,
#   'in_degree': 2415,
#   'degree': 4107},
#  415313: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 34,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ACTS_ON_Protein': 1,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 3,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 15,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 22,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 52,
#    'Protein_ASSOCIATED_WITH_Biological_process': 2,
#    'Protein_ASSOCIATED_WITH_Tissue': 166,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 23,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 36},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 39,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 365,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 9,
#    'Transcript_TRANSLATED_INTO_Protein': 3,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Analytical_sample_HAS_QUANTIFIED_PROTEIN_Protein': 11,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 36},
#   'out_degree': 371,
#   'in_degree': 464,
#   'degree': 835},
#  415314: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 496,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ACTS_ON_Protein': 7,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 9,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 12,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 2,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 432,
#    'Protein_ASSOCIATED_WITH_Biological_process': 16,
#    'Protein_ASSOCIATED_WITH_Tissue': 548,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 3045,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 93,
#    'Protein_HAS_STRUCTURE_Protein_structure': 16},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 41,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 389,
#    'Protein_ACTS_ON_Protein': 41,
#    'Drug_COMPILED_TARGETS_Protein': 10,
#    'Metabolite_ASSOCIATED_WITH_Protein': 4,
#    'Drug_ACTS_ON_Protein': 10,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 3,
#    'Transcript_TRANSLATED_INTO_Protein': 1,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Analytical_sample_HAS_QUANTIFIED_PROTEIN_Protein': 25,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 93},
#   'out_degree': 4693,
#   'in_degree': 618,
#   'degree': 5311},
#  415315: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 360,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 5,
#    'Protein_ACTS_ON_Protein': 18,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 8,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 8,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 217,
#    'Protein_ASSOCIATED_WITH_Biological_process': 20,
#    'Protein_ASSOCIATED_WITH_Tissue': 359,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 812,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 63,
#    'Protein_HAS_STRUCTURE_Protein_structure': 5},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 10,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 476,
#    'Protein_ACTS_ON_Protein': 24,
#    'Drug_COMPILED_TARGETS_Protein': 35,
#    'Metabolite_ASSOCIATED_WITH_Protein': 1,
#    'Drug_ACTS_ON_Protein': 70,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 5,
#    'Transcript_TRANSLATED_INTO_Protein': 2,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 63},
#   'out_degree': 1892,
#   'in_degree': 687,
#   'degree': 2579},
#  415317: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 106,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 4,
#    'Protein_ACTS_ON_Protein': 185,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 2,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 17,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 16,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 182,
#    'Protein_ASSOCIATED_WITH_Biological_process': 2,
#    'Protein_ASSOCIATED_WITH_Tissue': 283,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 109,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 147},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 74,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 379,
#    'Protein_ACTS_ON_Protein': 86,
#    'Drug_COMPILED_TARGETS_Protein': 60,
#    'Drug_ACTS_ON_Protein': 62,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 25,
#    'Transcript_TRANSLATED_INTO_Protein': 1,
#    'Functional_region_FOUND_IN_PROTEIN_Protein': 1,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Analytical_sample_HAS_QUANTIFIED_PROTEIN_Protein': 42,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 147},
#   'out_degree': 1070,
#   'in_degree': 878,
#   'degree': 1948},
#  415318: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 239,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
# ...
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 38},
#   'out_degree': 957,
#   'in_degree': 787,
#   'degree': 1744},
#  418081: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 621,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 3,
#    'Protein_ACTS_ON_Protein': 172,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 8,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 17,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 18,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 674,
#    'Protein_ASSOCIATED_WITH_Biological_process': 35,
#    'Protein_ASSOCIATED_WITH_Tissue': 863,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 3042,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 317,
#    'Protein_HAS_STRUCTURE_Protein_structure': 17},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 61,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 79,
#    'Protein_ACTS_ON_Protein': 81,
#    'Drug_COMPILED_TARGETS_Protein': 13,
#    'Metabolite_ASSOCIATED_WITH_Protein': 1,
#    'Drug_ACTS_ON_Protein': 14,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 29,
#    'Known_variant_CURATED_AFFECTS_INTERACTION_WITH_Protein': 1,
#    'Transcript_TRANSLATED_INTO_Protein': 1,
#    'Functional_region_FOUND_IN_PROTEIN_Protein': 1,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Analytical_sample_HAS_QUANTIFIED_PROTEIN_Protein': 29,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 317},
#   'out_degree': 5804,
#   'in_degree': 628,
#   'degree': 6432},
#  418085: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 113,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ACTS_ON_Protein': 110,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 3,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 9,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 4,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 129,
#    'Protein_ASSOCIATED_WITH_Biological_process': 3,
#    'Protein_ASSOCIATED_WITH_Tissue': 241,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 94,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 24},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 6,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 145,
#    'Protein_ACTS_ON_Protein': 94,
#    'Drug_COMPILED_TARGETS_Protein': 15,
#    'Drug_ACTS_ON_Protein': 42,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 2,
#    'Transcript_TRANSLATED_INTO_Protein': 2,
#    'Functional_region_FOUND_IN_PROTEIN_Protein': 1,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 24},
#   'out_degree': 747,
#   'in_degree': 332,
#   'degree': 1079},
#  418087: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 44,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ACTS_ON_Protein': 40,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 1,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 3,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 1,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 45,
#    'Protein_ASSOCIATED_WITH_Tissue': 227,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 33,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 34},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 29,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 340,
#    'Protein_ACTS_ON_Protein': 4,
#    'Drug_COMPILED_TARGETS_Protein': 11,
#    'Drug_ACTS_ON_Protein': 30,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 1,
#    'Transcript_TRANSLATED_INTO_Protein': 2,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Analytical_sample_HAS_QUANTIFIED_PROTEIN_Protein': 12,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 34},
#   'out_degree': 445,
#   'in_degree': 464,
#   'degree': 909},
#  418090: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 147,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 3,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 3,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 6,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 180,
#    'Protein_ASSOCIATED_WITH_Biological_process': 8,
#    'Protein_ASSOCIATED_WITH_Tissue': 338,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 148,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 74},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 23,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 177,
#    'Protein_ACTS_ON_Protein': 83,
#    'Transcript_TRANSLATED_INTO_Protein': 10,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Analytical_sample_HAS_QUANTIFIED_PROTEIN_Protein': 24,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 74},
#   'out_degree': 924,
#   'in_degree': 392,
#   'degree': 1316},
#  418093: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 112,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 5,
#    'Protein_ACTS_ON_Protein': 16,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 2,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 92,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 10,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 169,
#    'Protein_ASSOCIATED_WITH_Biological_process': 6,
#    'Protein_ASSOCIATED_WITH_Tissue': 269,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 175,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 59},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 157,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 2073,
#    'Protein_ACTS_ON_Protein': 3,
#    'Drug_COMPILED_TARGETS_Protein': 3,
#    'Metabolite_ASSOCIATED_WITH_Protein': 3,
#    'Drug_ACTS_ON_Protein': 5,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 12,
#    'Transcript_TRANSLATED_INTO_Protein': 1,
#    'Functional_region_FOUND_IN_PROTEIN_Protein': 2,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Analytical_sample_HAS_QUANTIFIED_PROTEIN_Protein': 32,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 59},
#   'out_degree': 932,
#   'in_degree': 2351,
#   'degree': 3283},
#  418096: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 93,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ACTS_ON_Protein': 109,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 3,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 1,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 6,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 146,
#    'Protein_ASSOCIATED_WITH_Biological_process': 2,
#    'Protein_ASSOCIATED_WITH_Tissue': 226,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 82,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 34},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 1,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 213,
#    'Protein_ACTS_ON_Protein': 93,
#    'Drug_COMPILED_TARGETS_Protein': 15,
#    'Drug_ACTS_ON_Protein': 37,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 3,
#    'Transcript_TRANSLATED_INTO_Protein': 1,
#    'Functional_region_FOUND_IN_PROTEIN_Protein': 1,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 34},
#   'out_degree': 719,
#   'in_degree': 399,
#   'degree': 1118},
#  418097: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 437,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ACTS_ON_Protein': 4,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 6,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 26,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 27,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 270,
#    'Protein_ASSOCIATED_WITH_Biological_process': 7,
#    'Protein_ASSOCIATED_WITH_Tissue': 441,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 776,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 49,
#    'Protein_HAS_STRUCTURE_Protein_structure': 5},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 51,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 461,
#    'Drug_COMPILED_TARGETS_Protein': 3,
#    'Metabolite_ASSOCIATED_WITH_Protein': 1,
#    'Drug_ACTS_ON_Protein': 10,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 16,
#    'Known_variant_CURATED_AFFECTS_INTERACTION_WITH_Protein': 2,
#    'Transcript_TRANSLATED_INTO_Protein': 3,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Analytical_sample_HAS_QUANTIFIED_PROTEIN_Protein': 41,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 49},
#   'out_degree': 2065,
#   'in_degree': 638,
#   'degree': 2703},
#  418098: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 59,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ACTS_ON_Protein': 9,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 3,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 14,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 66,
#    'Protein_ASSOCIATED_WITH_Biological_process': 1,
#    'Protein_ASSOCIATED_WITH_Tissue': 224,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 31,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 37},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 27,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 587,
#    'Protein_ACTS_ON_Protein': 1,
#    'Drug_ACTS_ON_Protein': 2,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 11,
#    'Transcript_TRANSLATED_INTO_Protein': 1,
#    'Functional_region_FOUND_IN_PROTEIN_Protein': 1,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 37},
#   'out_degree': 461,
#   'in_degree': 668,
#   'degree': 1129},
#  418101: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 296,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 26,
#    'Protein_ACTS_ON_Protein': 491,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 8,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 42,
#    'Protein_IS_SUBUNIT_OF_Complex': 2,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 58,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 296,
#    'Protein_ASSOCIATED_WITH_Biological_process': 22,
#    'Protein_ASSOCIATED_WITH_Tissue': 428,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 275,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 296,
#    'Protein_HAS_STRUCTURE_Protein_structure': 3},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 122,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 143,
#    'Protein_ACTS_ON_Protein': 155,
#    'Drug_COMPILED_TARGETS_Protein': 7,
#    'Drug_ACTS_ON_Protein': 11,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 59,
#    'Known_variant_CURATED_AFFECTS_INTERACTION_WITH_Protein': 1,
#    'Transcript_TRANSLATED_INTO_Protein': 3,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Analytical_sample_HAS_QUANTIFIED_PROTEIN_Protein': 46,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 296},
#   'out_degree': 2260,
#   'in_degree': 844,
#   'degree': 3104},
#  418105: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 148,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 18,
#    'Protein_ACTS_ON_Protein': 541,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 2,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 32,
#    'Protein_IS_SUBUNIT_OF_Complex': 1,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 21,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 116,
#    'Protein_ASSOCIATED_WITH_Biological_process': 12,
#    'Protein_ASSOCIATED_WITH_Tissue': 248,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 132,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 403,
#    'Protein_HAS_STRUCTURE_Protein_structure': 17},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 68,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 683,
#    'Protein_ACTS_ON_Protein': 298,
#    'Drug_COMPILED_TARGETS_Protein': 3,
#    'Drug_ACTS_ON_Protein': 2,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 18,
#    'Transcript_TRANSLATED_INTO_Protein': 1,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Analytical_sample_HAS_QUANTIFIED_PROTEIN_Protein': 23,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 403},
#   'out_degree': 1708,
#   'in_degree': 1500,
#   'degree': 3208},
#  418112: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 834,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 20,
#    'Protein_ACTS_ON_Protein': 39,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 5,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 18,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 1,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 257,
#    'Protein_ASSOCIATED_WITH_Biological_process': 9,
#    'Protein_ASSOCIATED_WITH_Tissue': 469,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 610,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 254,
#    'Protein_HAS_STRUCTURE_Protein_structure': 17},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 64,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 211,
#    'Protein_ACTS_ON_Protein': 75,
#    'Drug_COMPILED_TARGETS_Protein': 27,
#    'Metabolite_ASSOCIATED_WITH_Protein': 11,
#    'Drug_ACTS_ON_Protein': 28,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 10,
#    'Known_variant_CURATED_AFFECTS_INTERACTION_WITH_Protein': 1,
#    'Transcript_TRANSLATED_INTO_Protein': 2,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Analytical_sample_HAS_QUANTIFIED_PROTEIN_Protein': 52,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 254},
#   'out_degree': 2550,
#   'in_degree': 736,
#   'degree': 3286},
#  418113: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 234,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 3,
#    'Protein_ACTS_ON_Protein': 6,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 1,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 65,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 5,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 138,
#    'Protein_ASSOCIATED_WITH_Biological_process': 1,
#    'Protein_ASSOCIATED_WITH_Tissue': 229,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 219,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 45},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 92,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 1538,
#    'Protein_ACTS_ON_Protein': 7,
#    'Drug_COMPILED_TARGETS_Protein': 11,
#    'Drug_ACTS_ON_Protein': 24,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 9,
#    'Transcript_TRANSLATED_INTO_Protein': 2,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 45},
#   'out_degree': 963,
#   'in_degree': 1729,
#   'degree': 2692},
#  418114: {'node_out_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 188,
#    'Protein_HAS_SEQUENCE_Amino_acid_sequence': 1,
#    'Protein_DETECTED_IN_PATHOLOGY_SAMPLE_Disease': 16,
#    'Protein_ANNOTATED_IN_PATHWAY_Pathway': 4,
#    'Protein_ACTS_ON_Protein': 7,
#    'Protein_ASSOCIATED_WITH_Molecular_function': 6,
#    'Protein_HAS_MODIFIED_SITE_Modified_protein': 32,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 23,
#    'Protein_ASSOCIATED_WITH_Cellular_component': 133,
#    'Protein_ASSOCIATED_WITH_Biological_process': 8,
#    'Protein_ASSOCIATED_WITH_Tissue': 266,
#    'Protein_MENTIONED_IN_PUBLICATION_Publication': 158,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 58,
#    'Protein_HAS_STRUCTURE_Protein_structure': 1},
#   'node_in_degree_dict': {'Peptide_BELONGS_TO_PROTEIN_Protein': 78,
#    'Known_variant_VARIANT_FOUND_IN_PROTEIN_Protein': 664,
#    'Protein_ACTS_ON_Protein': 28,
#    'Drug_COMPILED_TARGETS_Protein': 5,
#    'Drug_ACTS_ON_Protein': 6,
#    'Protein_CURATED_INTERACTS_WITH_Protein': 10,
#    'Transcript_TRANSLATED_INTO_Protein': 3,
#    'Gene_TRANSLATED_INTO_Protein': 1,
#    'Analytical_sample_HAS_QUANTIFIED_PROTEIN_Protein': 28,
#    'Protein_COMPILED_INTERACTS_WITH_Protein': 58},
#   'out_degree': 901,
#   'in_degree': 881,
#   'degree': 1782},
#  ...}

# %%
node_dict[9]
# Out:
# {'node_in_degree_dict': {'Protein_ASSOCIATED_WITH_Disease': 8},
#  'node_out_degree_dict': {'Disease_HAS_PARENT_Disease': 1},
#  'out_degree': 1,
#  'in_degree': 8,
#  'degree': 9}

# %%
os.listdir(folder_path)
# Out:
# ['Protein__ASSOCIATED_WITH__Disease.csv',
#  'Clinical_variable__HAS_PARENT__Clinical_variable.csv',
#  'Protein__HAS_SEQUENCE__Amino_acid_sequence.csv',
#  'Known_variant__VARIANT_FOUND_IN_CHROMOSOME__Chromosome.csv',
#  'Protein__DETECTED_IN_PATHOLOGY_SAMPLE__Disease.csv',
#  'Transcript__LOCATED_IN__Chromosome.csv',
#  'Metabolite__ASSOCIATED_WITH__Disease.csv',
#  'Peptide__BELONGS_TO_PROTEIN__Protein.csv',
#  'Drug__CURATED_TARGETS__Gene.csv',
#  'Protein__ANNOTATED_IN_PATHWAY__Pathway.csv',
#  'User__IS_RESPONSIBLE__Project.csv',
#  'Known_variant__VARIANT_FOUND_IN_PROTEIN__Protein.csv',
#  'Protein__ACTS_ON__Protein.csv',
#  'Modification__HAS_PARENT__Modification.csv',
#  '.DS_Store',
#  'Biological_sample__SPLITTED_INTO__Analytical_sample.csv',
#  'Clinically_relevant_variant__ASSOCIATED_WITH__Disease.csv',
#  'Experimental_factor__MAPS_TO__Disease.csv',
#  'Biological_sample__BELONGS_TO_SUBJECT__Subject.csv',
#  'Project__STUDIES_TISSUE__Tissue.csv',
#  'User__PARTICIPATES_IN__Project.csv',
#  'Drug__COMPILED_TARGETS__Protein.csv',
#  'Tissue__MENTIONED_IN_PUBLICATION__Publication.csv',
#  'Modified_protein__MENTIONED_IN_PUBLICATION__Publication.csv',
#  'Cellular_component__HAS_PARENT__Cellular_component.csv',
#  'Protein__ASSOCIATED_WITH__Molecular_function.csv',
#  'Modified_protein__ASSOCIATED_WITH__Disease.csv',
#  'Metabolite__ASSOCIATED_WITH__Protein.csv',
#  'Peptide__HAS_MODIFIED_SITE__Modified_protein.csv',
#  'Project__HAS_ENROLLED__Subject.csv',
#  'Protein__HAS_MODIFIED_SITE__Modified_protein.csv',
#  'GWAS_study__PUBLISHED_IN__Publication.csv',
#  'Molecular_function__HAS_PARENT__Molecular_function.csv',
#  'Known_variant__VARIANT_FOUND_IN_GENE__Gene.csv',
#  'Protein__IS_SUBUNIT_OF__Complex.csv',
#  'Drug__ACTS_ON__Protein.csv',
#  'Protein__CURATED_INTERACTS_WITH__Protein.csv',
#  'Modified_protein__IS_SUBSTRATE_OF__Protein.csv',
#  'Functional_region__MENTIONED_IN_PUBLICATION__Publication.csv',
#  'Drug__MENTIONED_IN_PUBLICATION__Publication.csv',
#  'Cellular_component__MENTIONED_IN_PUBLICATION__Publication.csv',
#  'Drug__INTERACTS_WITH__Drug.csv',
#  'Protein__ASSOCIATED_WITH__Cellular_component.csv',
#  'Experimental_factor__MAPS_TO__Phenotype.csv',
#  'Protein__ASSOCIATED_WITH__Biological_process.csv',
#  'Metabolite__ANNOTATED_IN_PATHWAY__Pathway.csv',
#  'Known_variant__CURATED_AFFECTS_INTERACTION_WITH__Protein.csv',
#  'Modified_protein__HAS_MODIFICATION__Modification.csv',
#  'Known_variant__VARIANT_IS_CLINICALLY_RELEVANT__Clinically_relevant_variant.csv',
#  'Tissue__HAS_PARENT__Tissue.csv',
#  'Transcript__TRANSLATED_INTO__Protein.csv',
#  'Known_variant__VARIANT_FOUND_IN_GWAS__GWAS_study.csv',
#  'Functional_region__FOUND_IN_PROTEIN__Protein.csv',
#  'Gene__TRANSLATED_INTO__Protein.csv',
#  'GWAS_study__STUDIES_TRAIT__Experimental_factor.csv',
#  'Analytical_sample__HAS_QUANTIFIED_MODIFIED_PROTEIN__Modified_protein.csv',
#  'Protein__ASSOCIATED_WITH__Tissue.csv',
#  'Protein__MENTIONED_IN_PUBLICATION__Publication.csv',
#  'Phenotype__HAS_PARENT__Phenotype.csv',
#  'Protein__IS_QCMARKER_IN_TISSUE__Tissue.csv',
#  'Gene__TRANSCRIBED_INTO__Transcript.csv',
#  'Analytical_sample__HAS_QUANTIFIED_PROTEIN__Protein.csv',
#  'Modified_protein__ASSOCIATED_WITH__Biological_process.csv',
#  'Complex__ASSOCIATED_WITH__Biological_process.csv',
#  'Experimental_factor__HAS_PARENT__Experimental_factor.csv',
#  'Disease__HAS_PARENT__Disease.csv',
#  'Protein__COMPILED_INTERACTS_WITH__Protein.csv',
#  'Protein__HAS_STRUCTURE__Protein_structure.csv',
#  'Protein__IS_BIOMARKER_OF_DISEASE__Disease.csv',
#  'Drug__TARGETS_CLINICALLY_RELEVANT_VARIANT__Clinically_relevant_variant.csv',
#  'Biological_process__HAS_PARENT__Biological_process.csv',
#  'Experiment__HAS_PARENT__Experiment.csv',
#  'Project__STUDIES_DISEASE__Disease.csv',
#  'Units__HAS_PARENT__Units.csv',
#  'Experimental_factor__MAPS_TO__Clinical_variable.csv']

# %%
## Write to db
with graphRetriever.driver.session() as session:
    for key in tqdm(node_dict):
        property_dict = node_dict[key]
        query = f'''MATCH (n)
            WHERE id(n) = {key} AND NOT exists(n.degree_dict)
            SET n.degree_dict = "{property_dict}"'''
        session.run(query)
# Out:
#   0%|          | 0/16445695 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [16], in <cell line: 2>()
#       4 property_dict = node_dict[key]
#       5 query = f'''MATCH (n)
#       6     WHERE id(n) = {key} AND NOT exists(n.degree_dict)
#       7     SET n.degree_dict = "{property_dict}"'''
# ----> 8 session.run(query)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/neo4j/_sync/work/session.py:307, in Session.run(self, query, parameters, **kwargs)
#     304 cx = self._connection
#     306 cx.telemetry(TelemetryAPI.AUTO_COMMIT)
# --> 307 self._auto_result = Result(
#     308     cx, self._config.fetch_size, self._result_closed,
#     309     self._result_error
#     310 )
#     311 bookmarks = self._get_bookmarks()
#     312 parameters = dict(parameters or {}, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/neo4j/_sync/work/result.py:83, in Result.__init__(self, connection, fetch_size, on_closed, on_error)
#      82 def __init__(self, connection, fetch_size, on_closed, on_error):
# ---> 83     self._connection = ConnectionErrorHandler(
#      84         connection, self._connection_error_handler
#      85     )
#      86     self._hydration_scope = connection.new_hydration_scope()
#      87     self._on_error = on_error
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/neo4j/_sync/io/_common.py:167, in ConnectionErrorHandler.__init__(self, connection, on_error)
#     159 def __init__(self, connection, on_error):
#     160     """
#     161     :param connection the connection object to warp
#     162     :type connection Bolt
#    (...)
#     165     :type on_error callable
#     166     """
# --> 167     self.__connection = connection
#     168     self.__on_error = on_error
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/neo4j/_sync/io/_common.py:200, in ConnectionErrorHandler.__setattr__(self, name, value)
#     199 def __setattr__(self, name, value):
# --> 200     if name.startswith("_" + self.__class__.__name__ + "__"):
#     201         super().__setattr__(name, value)
#     202     else:
#
# KeyboardInterrupt:
